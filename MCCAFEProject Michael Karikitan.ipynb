# %%
#coffee
Espresso=1.50
Americano=2
Caffelatte=2.25
Mocha=2.25
Capuccino=2.50
Machiato=2.50
#tea
Whitetea=1.50
Greentea=2.00
Oolongtea=2.25
Blacktea=2.25
EarlGrey=2.50
Matcha=2.50

#Pastry
Croissant=5.50
Cinnamonroll=4.50
Bananabread=4.25
Pumpkinbread=3.75
Stickybun=4.25
Appleturnover=3.75

print("Welcome to MC'CAFE! \n\nToday's specials are COFFE , TEA'S AND PASTRIES!.")    
    
print()
menu={'Espresso':'$1.50','Americano':'$2.00','Caffelatte':'$2.25','Mocha':'$2.25','Capuccino':'$2.50','Machiato':'$2.50','\n\nWhitetea':'$1.50','Greentea':'$2.00','Oolongtea':'$2.25','Blacktea':'$2.25','Earlgrey':'$2.50','Matcha':'$2.50',
      '\n\nCroissant':'$5.50','Cinnamonroll':'$4.50','Bananabread':'$4.25','Pumpkinbread':'$3.75','Stickybun':'$4.25','Appleturnover':'$3.75',
      "\n\n\nPress 'd' ":"complete order"}
coffee=0
tea=0
pastry=0
while True:
    for i in menu:
        print(f"{i}={menu[i]}")
    print()
 
    Condition=True
    while(Condition):
        food=input('Select your COFFEE, TEA or have some Pastries from the menu:')
        food=food.capitalize()
 
        if food == 'Espresso':
              quantity=int(input('Quantity:'))
              coffee+=quantity
              Condition=False
            
        elif food == 'Americano':
             quantity=int(input('Quantity:'))
             coffee+=quantity
             Condition=False
        elif food == 'Caffelatte':
             quantity=int(input('Quantity:'))
             coffee+=quantity
             Condition=False
        elif food == 'Mocha':
             quantity=int(input('Quantity:'))
             coffee+=quantity
             Condition=False
        elif food == 'Capuccino':
             quantity=int(input('Quantity:'))
             coffee+=quantity
             Condition=False
        elif food == 'Machiato':
             quantity=int(input('Quantity:'))
             coffee+=quantity
             Condition=False
        elif food == 'Whitetea':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
                
        elif food == 'Greentea':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
        elif food == 'Oolongtea':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
        elif food == 'Blacktea':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
        elif food == 'Earlgrey':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
        elif food == 'Matcha':
             quantity=int(input('Quantity:'))
             tea+=quantity
             Condition=False
        elif food == 'Croissant ':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
        elif food == 'Cinammonroll':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
        elif food == 'Bananabread':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
        elif food == 'Pumpkinbread':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
        elif food == 'Stickybun':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
        elif food == 'Appleturnover':
             quantity=int(input('Quantity:'))
             pastry+=quantity
             Condition=False
                
        elif food=='D':
            condition=False
            amount=( coffee*4)+(tea*3)+(pastry*2)
            mem=input('Do u have membership here in MONTGOMERY COLLEGE CAFETERIA?( Enter Y for yes, N for no):')
            mem=mem.capitalize()
            
            if amount>=10 and mem=='Y':
                purchaseDisc=amount*0.05
                memDisc=(amount-purchaseDisc)*0.15
                befTotal=(amount-purchaseDisc-memDisc)
                marylandtax=befTotal*0.07
                total=befTotal+marylandtax
 
            elif amount<10 and mem=='Y':
                purchaseDisc=0
                memDisc=amount*0.15
                befTotal=amount-memDisc
                marylandtax=befTotal*0.07
                total=befTotal+marylandtax
 
            elif amount>=10 and mem=='N':
                purchaseDisc=amount*0.05
                memDisc=0
                befTotal=amount-purchaseDisc
                marylandtax=befTotal*0.07
                total=befTotal+marylandtax
 
            else:
                purchaseDisc=0
                memDisc=0
                befTotal=amount
                marylandtax=befTotal*0.07
                total=befTotal+marylandtax
 
 
            print()
            print('THANK YOU FOR VISITING MCCAFE!')
            print('Receipt')
            print('==============================')
            print(f'{"food":5s}:               {food:>1s}')
            print(f'{"Quantity":8s}:{quantity:>13}')
            print(f'{"Member":6s}:{mem:>15}')
            print(f'{"Amount":6s}:{"$":>15}{amount:>5.2f}')
            print(f'{"Purchase Disc.":14s}{"$":>8}{purchaseDisc:>5.2f}')
            print(f'{"Member Disc.":12s}{"$":>10}{memDisc:>5.2f}')
            print(f'{"Total (bef. MST)":16s}{"$":>6}{befTotal:>5.2f}')
            print(f'{"Maryland Tax":3s}{"$":>19}{marylandtax:>5.2f}')
            print(f'{"Total (incl. Maryland Tax)":17s}{"$":>5}{total:>5.2f}')
            exit()
        else:
             print('Please enter a food from the menu!')
             Condition=True
# Out:
# Welcome to MC'CAFE!
#
# Today's specials are COFFE , TEA'S AND PASTRIES!.
#
# Espresso=$1.50
# Americano=$2.00
# Caffelatte=$2.25
# Mocha=$2.25
# Capuccino=$2.50
# Machiato=$2.50
#
#
# Whitetea=$1.50
# Greentea=$2.00
# Oolongtea=$2.25
# Blacktea=$2.25
# Earlgrey=$2.50
# Matcha=$2.50
#
#
# Croissant=$5.50
# Cinnamonroll=$4.50
# Bananabread=$4.25
# Pumpkinbread=$3.75
# Stickybun=$4.25
# Appleturnover=$3.75
#
#
#
# Press 'd' =complete order
#
# Select your COFFEE, TEA or have some Pastries from the menu:d
# Do u have membership here in MONTGOMERY COLLEGE CAFETERIA?( Enter Y for yes, N for no):n
#
# THANK YOU FOR VISITING MCCAFE!
# Receipt
# ...
# food :               D
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1018460e1dec> in <module>
#     156             print('==============================')
# ...
